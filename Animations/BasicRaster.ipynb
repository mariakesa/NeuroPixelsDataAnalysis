# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path='/media/maria/DATA1/Documents/NeuroMatchAcademy2020_dat/unzipped_files/Moniz_2017-05-15.tar'
spike_times = np.load(data_path+'/'+'spikes.times.npy') * 1000

# %%
spike_time_cells=np.load('/media/maria/DATA1/Documents/documents/NeuroPixelsDataAnalysis/GUI/spike_time_cells.npy',allow_pickle=True)/1000

# %%
x=[]
y=[]
for n in range(len(spike_time_cells)):
    x+=list(spike_time_cells[n][(10<spike_time_cells[n]) & (spike_time_cells[n]<11)])
    y+=[n]*len(list(spike_time_cells[n][(10<spike_time_cells[n]) & (spike_time_cells[n]<11)]))

# %%
plt.scatter(x,y,s=0.1)

# %%
for j in range(0,10):
    x+=list(spike_time_cells[n][(10+j*0.1<spike_time_cells[n]) & (spike_time_cells[n]<11+j*0.1)])
    y+=[n]*len(list(spike_time_cells[n][(10+j*0.1<spike_time_cells[n]) & (spike_time_cells[n]<11+j*0.1)]))
    plt.scatter(x,y,s=0.1)
    plt.show()
