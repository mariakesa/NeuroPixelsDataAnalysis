# %%
import numpy as np

# %%
fl=np.load( '/media/maria/DATA1/Documents/NeuroMatchAcademy2020_dat/unzipped_files/Cori_2016-12-14.tar/clusters.templateWaveforms.npy' )
fl2=np.load('/media/maria/DATA1/Documents/NeuroMatchAcademy2020_dat/unzipped_files/Cori_2016-12-14.tar/clusters.peakChannel.npy' )

# %%
fl2.shape
# Out:
# (1085, 1)

# %%
print(fl2)
# Out:
# [[224.]
#  [316.]
#  [172.]
#  ...
#  [449.]
#  [713.]
#  [438.]]

# %%
plt.plot(fl2[:])

# %%
fl.shape
# Out:
# (1085, 82, 50)

# %%
import matplotlib.pyplot as plt

plt.plot(fl[100,:,6])

# %%
inputfilename='/media/maria/DATA1/Documents/NeuroPixelsData/rawDataSample.bin'

# %%
import numpy as np

with open(inputfilename, 'rb') as fid:
    data_array = np.fromfile(fid, np.int16).reshape(-1,385)

# %%
data_array=data_array.reshape(385,-1)

# %%
plt.plot(data_array.T[:10000,0])
