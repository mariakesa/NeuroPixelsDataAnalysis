# %%
import numpy as np

# %%
foreground_data=np.load('pcs.npy')
background_data=np.load('pcs_poisson.npy')
labs=np.load('labels.npy')

# %%
from contrastive import CPCA

mdl = CPCA()
projected_data = mdl.fit_transform(foreground_data, background_data, plot=True,active_labels=labs)
# Out:
# /home/maria/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
